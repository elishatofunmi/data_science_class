# %% [markdown]
# # An overview of what Data Science is all about

# %% [markdown]
# Data science is an interdisciplinary field that uses scientific methods, processes, algorithms and systems to extract knowledge and insights from data in various forms, both structured and unstructured,[1][2] similar to data mining.
# https://en.wikipedia.org/wiki/Data_science
#
#
# Data science is basically a field of machine learning that involves the comprehensive understanding of what data is all about.
# It is a field that involve statistics, mathematical analysis, intuitive thoughts e.t.c.

# %% [markdown]
# what do we mean by scientific methods?
# what we mean by scientific methods can also be termed to imply scientific theories, from the idea to theory

# %% [markdown]
# # What then do we Imply by all this terminologies?

# %% [markdown]
# To dive into the field of data science, there are certain conditions need to be satisfied:

# %%
images= ['data_geek.jpeg', 'data_loss.jpeg','data_science.jpeg','more_on_ds.jpeg']

import numpy as np
import matplotlib.pyplot as plt

w=20
h=20
fig=plt.figure(figsize=(40, 40))
columns = 4
rows = 1
for i, image in zip(range(1, columns*rows +1), images):
    img=mpimg.imread(image)
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
plt.show()

# %% [markdown]
# from the plot above one could infer to know all that is needed to get started in the field of data science
#
# from the first image:-
# as a data scientist you need to be proficient in the following: Domain Knowledge, science and Engineering.
# as an expert in the field of domain knowledge, you have to be good at marketing, advertising e.t.c
# as an expert in the field of science you need to be good with the application of machine learning in making sense out of your data;
# statistics is needed, since we are dealing with data, we have to work through the statistics inferred from your dataset.
# also, Your analytics skills which involves you putting together the maths.
#
# The engineering aspect is all about how are you developing your data science skills (i.e what tool), this includes, python, java, hadoop, spark e.t.c

# %%
from the second image:
we could see the following, hacking skills, maths and statistics knowledge, substantive expertise, research and lot more.
